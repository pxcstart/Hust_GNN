# %% [markdown]
# #####  挑战1：完成步骤一中的环境配置，使可以进行步骤二中的节点编码。
# #####  挑战2：代码漏洞检测是一个图级的二分类问题，它在对图节点编码的基础上，进一步得到图级的编码。
# #####        实现一个Readout层(src/process/model.py)，从节点编码得到代码图的编码表示，从而可以完成步骤三中的模型训练和评估。
# #####  挑战3：在使用所有训练数据条件下，修改代码的图表示或者模型，使模型的预测准确率达到55%以上(此挑战会根据准确率的提升酌情加分,最高满分)。
# #####

# %%
# 一.环境安装
# 安装并激活python环境, 已经验证的版本是3.7.2
# !python --version 
# !conda create -n devign python=3.7.2 #此命令不要重复执行，成功后可注释掉
# !conda activate devign    
# 根据当前机器的情况安装torch、torch-geometric、torch-sparse 和 torch-scatter
#   具体安装方法参考 https://pytorch.org/get-started/locally/ 
# 安装当前试验所依赖的python包
# !pip install -r requirements.txt

# %%
# 原始的代码数据集存放在 data/raw (Paths.raw)中
# 每一条数据包含：
# project名，commit_id，target（是否为漏洞代码），func（函数代码文本）
# 我们探索一下原始数据的构成
import pandas as pd
dataset = pd.read_json("data/raw/dataset.json")
dataset.head(5)
# Out:
#   project                                 commit_id  target  \
# 0  FFmpeg  973b1a6b9070e2bf17d17568cbaf4043ce931f51       0
# 1  FFmpeg  321b2a9ded0468670b7678b7c098886930ae16b2       0
# 2  FFmpeg  5d5de3eba4c7890c2e8077f5b4ae569671d11cf8       0
# 3  FFmpeg  32bf6550cb9cc9f487a6722fe2bfc272a93c1065       0
# 4  FFmpeg  57d77b3963ce1023eaf5ada8cba58b9379405cc8       0
#
#                                                 func
# 0  static av_cold int vdadec_init(AVCodecContext ...
# 1  static int transcode(AVFormatContext **output_...
# 2  static void v4l2_free_buffer(void *opaque, uin...
# 3  int ff_get_wav_header(AVFormatContext *s, AVIO...
# 4  int av_opencl_buffer_write(cl_mem dst_cl_buf, ...

# %%
# 使用joern工具将代码数据转化为CPG图
# 生成过程比较慢而且需要安装环境，在此省略
# 感兴趣的同学可以了解一下joern： https://docs.joern.io/home
# 生成的代码图数据存放在data/cpg (Paths.cpg)中，其中每100条数据写入一个文件
# 解压代码图数据
# !tar -xvzf cpg.tar.gz
# Out:
# data/cpg/
# data/cpg/36_cpg.pkl
# data/cpg/38_cpg.pkl
# data/cpg/22_cpg.pkl
# data/cpg/2_cpg.pkl
# data/cpg/4_cpg.pkl
# data/cpg/26_cpg.pkl
# data/cpg/13_cpg.pkl
# data/cpg/19_cpg.pkl
# data/cpg/16_cpg.pkl
# data/cpg/20_cpg.pkl
# data/cpg/12_cpg.pkl
# data/cpg/30_cpg.pkl
# data/cpg/8_cpg.pkl
# data/cpg/24_cpg.pkl
# data/cpg/33_cpg.pkl
# data/cpg/37_cpg.pkl
# data/cpg/29_cpg.pkl
# data/cpg/10_cpg.pkl
# data/cpg/28_cpg.pkl
# data/cpg/25_cpg.pkl
# data/cpg/3_cpg.pkl
# data/cpg/32_cpg.pkl
# data/cpg/6_cpg.pkl
# data/cpg/15_cpg.pkl
# data/cpg/11_cpg.pkl
# data/cpg/1_cpg.pkl
# data/cpg/34_cpg.pkl
# data/cpg/7_cpg.pkl
# data/cpg/35_cpg.pkl
# data/cpg/0_cpg.pkl
# data/cpg/21_cpg.pkl
# data/cpg/5_cpg.pkl
# data/cpg/9_cpg.pkl
# data/cpg/17_cpg.pkl
# data/cpg/31_cpg.pkl
# data/cpg/18_cpg.pkl
# data/cpg/14_cpg.pkl
# data/cpg/27_cpg.pkl
# data/cpg/23_cpg.pkl

# %%
# 二.图节点代码文本编码
# 训练用于编码节点中文本的word2vec模型，并对节点的文本进行编码
import main
main.setup()
main.embed_task()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 5619 to 6222
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  97 non-null     int64
#  1   func    97 non-null     object
#  2   Index   97 non-null     int64
#  3   cpg     97 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 89.3 KB
# Saving input dataset 8_cpg with size 97.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 1373 to 1962
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  98 non-null     int64
#  1   func    98 non-null     object
#  2   Index   98 non-null     int64
#  3   cpg     98 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 87.2 KB
# CPG cut - original nodes: 229 to max: 205
# Saving input dataset 2_cpg with size 98.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 23940 to 24609
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 89.0 KB
# CPG cut - original nodes: 206 to max: 205
# CPG cut - original nodes: 246 to max: 205
# Saving input dataset 34_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 21948 to 22608
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 82.3 KB
# Saving input dataset 31_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 25894 to 26704
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 85.4 KB
# CPG cut - original nodes: 209 to max: 205
# Saving input dataset 37_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 13715 to 14355
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 83.2 KB
# CPG cut - original nodes: 281 to max: 205
# Saving input dataset 20_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 8330 to 9005
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  98 non-null     int64
#  1   func    98 non-null     object
#  2   Index   98 non-null     int64
#  3   cpg     98 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 87.3 KB
# Saving input dataset 12_cpg with size 98.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 22617 to 23254
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 84.6 KB
# Saving input dataset 32_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 12429 to 13199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 85.5 KB
# CPG cut - original nodes: 227 to max: 205
# Saving input dataset 18_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 26716 to 27298
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  76 non-null     int64
#  1   func    76 non-null     object
#  2   Index   76 non-null     int64
#  3   cpg     76 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 65.6 KB
# CPG cut - original nodes: 270 to max: 205
# Saving input dataset 38_cpg with size 76.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 3382 to 4092
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  102 non-null    int64
#  1   func    102 non-null    object
#  2   Index   102 non-null    int64
#  3   cpg     102 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 94.6 KB
# CPG cut - original nodes: 287 to max: 205
# Saving input dataset 5_cpg with size 102.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 13205 to 13712
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 86.3 KB
# Saving input dataset 19_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 1964 to 2695
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  101 non-null    int64
#  1   func    101 non-null    object
#  2   Index   101 non-null    int64
#  3   cpg     101 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 93.0 KB
# Saving input dataset 3_cpg with size 101.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 2701 to 3370
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 84.2 KB
# CPG cut - original nodes: 206 to max: 205
# Saving input dataset 4_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 18334 to 19124
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 81.5 KB
# CPG cut - original nodes: 342 to max: 205
# CPG cut - original nodes: 228 to max: 205
# Saving input dataset 26_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 19842 to 20565
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  103 non-null    int64
#  1   func    103 non-null    object
#  2   Index   103 non-null    int64
#  3   cpg     103 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 88.9 KB
# Saving input dataset 28_cpg with size 103.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 4095 to 4857
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 92.5 KB
# Saving input dataset 6_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 6244 to 6878
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 92.4 KB
# Saving input dataset 9_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 668 to 1372
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 87.3 KB
# CPG cut - original nodes: 236 to max: 205
# CPG cut - original nodes: 237 to max: 205
# Saving input dataset 1_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 7688 to 8327
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 84.7 KB
# Saving input dataset 11_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 6879 to 7686
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 90.6 KB
# CPG cut - original nodes: 212 to max: 205
# Saving input dataset 10_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 14359 to 15157
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 86.5 KB
# CPG cut - original nodes: 216 to max: 205
# CPG cut - original nodes: 214 to max: 205
# Saving input dataset 21_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 20578 to 21227
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  98 non-null     int64
#  1   func    98 non-null     object
#  2   Index   98 non-null     int64
#  3   cpg     98 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 85.6 KB
# CPG cut - original nodes: 230 to max: 205
# Saving input dataset 29_cpg with size 98.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 9010 to 9614
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  105 non-null    int64
#  1   func    105 non-null    object
#  2   Index   105 non-null    int64
#  3   cpg     105 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 98.9 KB
# Saving input dataset 13_cpg with size 105.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 16973 to 17585
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 85.0 KB
# Saving input dataset 24_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 25303 to 25889
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 91.8 KB
# CPG cut - original nodes: 266 to max: 205
# CPG cut - original nodes: 290 to max: 205
# CPG cut - original nodes: 226 to max: 205
# Saving input dataset 36_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 21233 to 21947
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  98 non-null     int64
#  1   func    98 non-null     object
#  2   Index   98 non-null     int64
#  3   cpg     98 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 89.8 KB
# CPG cut - original nodes: 233 to max: 205
# Saving input dataset 30_cpg with size 98.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 17597 to 18330
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 87.9 KB
# Saving input dataset 25_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 11031 to 11665
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 90.0 KB
# Saving input dataset 16_cpg with size 100.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 23255 to 23929
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 88.6 KB
# Saving input dataset 33_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 19146 to 19836
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  105 non-null    int64
#  1   func    105 non-null    object
#  2   Index   105 non-null    int64
#  3   cpg     105 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 92.5 KB
# Saving input dataset 27_cpg with size 105.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 15920 to 16972
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 81.6 KB
# Saving input dataset 23_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 24616 to 25299
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  98 non-null     int64
#  1   func    98 non-null     object
#  2   Index   98 non-null     int64
#  3   cpg     98 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 82.8 KB
# Saving input dataset 35_cpg with size 98.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 9649 to 10449
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  97 non-null     int64
#  1   func    97 non-null     object
#  2   Index   97 non-null     int64
#  3   cpg     97 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 85.8 KB
# Saving input dataset 14_cpg with size 97.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 4862 to 5618
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 89.2 KB
# Saving input dataset 7_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 11677 to 12421
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  97 non-null     int64
#  1   func    97 non-null     object
#  2   Index   97 non-null     int64
#  3   cpg     97 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 80.3 KB
# Saving input dataset 17_cpg with size 97.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 10452 to 11029
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  99 non-null     int64
#  1   func    99 non-null     object
#  2   Index   99 non-null     int64
#  3   cpg     99 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 87.1 KB
# CPG cut - original nodes: 328 to max: 205
# CPG cut - original nodes: 226 to max: 205
# Saving input dataset 15_cpg with size 99.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 2 to 665
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  98 non-null     int64
#  1   func    98 non-null     object
#  2   Index   98 non-null     int64
#  3   cpg     98 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 86.4 KB
# Saving input dataset 0_cpg with size 98.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 15174 to 15908
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  100 non-null    int64
#  1   func    100 non-null    object
#  2   Index   100 non-null    int64
#  3   cpg     100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 90.4 KB
# Saving input dataset 22_cpg with size 100.
# Saving w2vmodel.

# %%
# 三.模型训练和验证
main.process_task(True, False)
# Out:
# The model has 481,200 trainable parameters
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 2 to 665
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 6879 to 7686
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 7688 to 8327
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 8330 to 9005
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 9010 to 9614
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   105 non-null    object
#  1   target  105 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.7 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 9649 to 10449
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   97 non-null     object
#  1   target  97 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.3 KB
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 10452 to 11029
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 11031 to 11665
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 11677 to 12421
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   97 non-null     object
#  1   target  97 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.3 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 12429 to 13199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 13205 to 13712
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 668 to 1372
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 13715 to 14355
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 14359 to 15157
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 15174 to 15908
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 15920 to 16972
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 16973 to 17585
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   99 non-null     object
#  1   target  99 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 17597 to 18330
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 18334 to 19124
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   target  100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.5 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105 entries, 19146 to 19836
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   105 non-null    object
#  1   target  105 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.7 KB
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 19842 to 20565
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   103 non-null    object
#  1   target  103 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 20578 to 21227
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 1373 to 1962
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   98 non-null     object
#  1   target  98 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 5.4 KB
# Splitting Dataset
# train with cuda.
# /home/pxc/devign_lab-main/src/data/datamanager.py:114: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataset = dataset.append(load(data_sets_dir, ds_file))
# /home/pxc/devign_lab-main/src/data/datamanager.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train = train_false.append(train_true)
# /home/pxc/devign_lab-main/src/data/datamanager.py:90: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   val = val_false.append(val_true)
# /home/pxc/devign_lab-main/src/data/datamanager.py:91: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test_false.append(test_true)
# /home/pxc/anaconda3/lib/python3.9/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 三.模型训练和验证
# ----> 2 main.process_task(True, False)
#
# File ~/devign_lab-main/main.py:181, in process_task(stopping, test_only)
#     174 if stopping:
#     175     early_stopping = process.EarlyStopping(
#     176         model,
#     177         patience=context.patience,
#     178         verbose=PROCESS_PARAMS.verbose,
#     179         delta=PROCESS_PARAMS.delta,
#     180     )
# --> 181     train(train_loader_step, val_loader_step, early_stopping)
#     182     model.load()
#     183 else:
#
# File ~/devign_lab-main/src/process/modeling.py:17, in Train.__call__(self, train_loader_step, val_loader_step, early_stopping)
#      15 for epoch in range(self.epochs):
#      16     self.step.train()
# ---> 17     train_stats = train_loader_step(self.step)
#      18     self.history(train_stats, epoch + 1)
#      20     if val_loader_step is not None:
#
# File ~/devign_lab-main/src/process/loader_step.py:16, in LoaderStep.__call__(self, step)
#      14 for i, batch in enumerate(self.loader):
#      15     batch.to(self.device)
# ---> 16     stat: stats.Stat = step(i, batch, batch.y)
#      17     self.stats(stat)
#      19 return self.stats
#
# File ~/devign_lab-main/src/process/step.py:19, in Step.__call__(self, i, x, y)
#      18 def __call__(self, i, x, y):
# ---> 19     out = self.model(x)
#      20     loss = self.criterion(out, y.float())
#      21     acc = softmax_accuracy(out, y.float())
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/devign_lab-main/src/process/model.py:45, in forward(self, data)
#      43 def forward(self, data):
#      44     x, edge_index = data.x, data.edge_index
# ---> 45     x = self.ggc(x, edge_index)
#      46     x = self.readout(x, data.x)
#      48     return x
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/devign_lab-main/src/process/model.py:33, in Readout.forward(self, h, x)
#      31 def forward(self, h, x):
#      32     # TODO
# ---> 33     breakpoint()
#      34     raise NotImplementedError
#
# NotImplementedError:
